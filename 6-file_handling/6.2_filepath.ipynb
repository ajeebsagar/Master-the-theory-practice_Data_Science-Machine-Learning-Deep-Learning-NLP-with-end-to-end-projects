# %%
import os
cwd=os.getcwd()
print(f"Current working directory: {cwd}")
# Out:
# Current working directory: c:\Users\AJEEB SAGAR\Desktop\udemby\6-file_handling

# %%
## create a new directory

new_directory="package"
os.mkdir(new_directory)
print(f"New directory '{new_directory}' created.")
# Out:
# New directory 'package' created.

# %%
## listing files and directories

items=os.listdir('.')
print(items)
# Out:
# ['6.2_filepath.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'fileoperation.ipynb', 'package']

# %%
### joining paths
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(), dir_name,file_name)
print(full_path)
# Out:
# c:\Users\AJEEB SAGAR\Desktop\udemby\6-file_handling\folder\file.txt

# %%
path='example.txt'
if os.path.exists(path):
    print(f"the path '{path}' exists")
else:
    print(f"the path '{path}' does not exists")
# Out:
# the path 'example.txt' exists

# %%
## checking if a path is a file or directory

import os
path='example.txt'
if os.path.isfile(path):
    print(f"the path '{path}' is a file.")
elif os.path.isdir(path):
    print("the path '{path}' is a directory")
else:
    print(f"the path '{path}' is neither a file nor a directory.")
# Out:
# the path 'example.txt' is a file.

# %%
## detting the absolute path

relative_path='example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\AJEEB SAGAR\Desktop\udemby\6-file_handling\example.txt
