# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt, pi
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np
np.array([1, 2, 3, 4, 5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from package.math import addition
print(addition(5, 10))
# Out:
# 15

# %%
from package import maths
maths.addition(5, 10)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from package import maths
#       2 maths.addition(5, 10)
#
# ImportError: cannot import name 'maths' from 'package' (c:\Users\AJEEB SAGAR\Desktop\udemby\5_module\package\__init__.py)
