# %% [markdown]
# Multi threading and multi processing
#
# 1 program
# 2 process
# 3 threads
# 5 example of process and thread.
#
#
# 1 program-> A program is a sequence if instructions written in programming language [eg:- python, c++]
#
# eg= google chrome
