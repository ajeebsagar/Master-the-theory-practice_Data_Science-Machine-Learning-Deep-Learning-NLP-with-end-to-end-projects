# %% [markdown]
# Iterators
#
# Iterators are advanced Python concepts that allow for efficient looping and memory management. Iterators provide a way to access elements of a collection sequentially without exposing the underlying structure.

# %%
my_list=[1,2,3,4,5]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
type (my_list)
# Out:
# list

# %%
print(type(my_list))
# Out:
# <class 'list'>

# %%
### iteraator

iterator = iter(my_list)
print(next(iterator))
print(next(iterator))
print(type(iterator))
# Out:
# 1
# 2
# <class 'list_iterator'>

# %%
iterator

# %%
### iteratte through all the element

next(iterator)
# Out:
# 3

# %%
iterator = iter(my_list)

try:
    print(next(iterator))
except StopIteration:
    print("they are no element in the iterator")
# Out:
# 1
