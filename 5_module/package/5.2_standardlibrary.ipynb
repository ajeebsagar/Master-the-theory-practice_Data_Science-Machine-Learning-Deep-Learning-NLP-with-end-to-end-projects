# %%
import array
arr=array.array('i', [1, 2, 3, 4, 5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(16))  
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random

import random
print(random.randint(1, 10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 6
# banana

# %%
### file and directory access

import os
print(os.getcwd())
# Out:
# c:\Users\AJEEB SAGAR\Desktop\udemby\5_module\package

# %%
os.mkdir('test_directory')

# %%
## high level operation on filed and collections of files

import shutil
shutil.copy('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
### data serialization

import json
data = {'name': 'Ajeeb', 'age': 30}
json_string = json.dumps(data)
print(json_string)
print(type(json_string))

parsed_data = json.loads(json_string)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Ajeeb", "age": 30}
# <class 'str'>
# {'name': 'Ajeeb', 'age': 30}
# <class 'dict'>

# %%
## csv

import csv
with open('example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age'])
    writer.writerow(['Ajeeb', 30])
    writer.writerow(['Sagar', 25])  
with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age']
# ['Ajeeb', '30']
# ['Sagar', '25']

# %%
## datetime

from datetime import datetime, timedelta
now = datetime.now()
print("Current date and time:", now)
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# Current date and time: 2025-08-02 23:57:17.361936
# 2025-08-02 23:57:17.361936
# 2025-08-01 23:57:17.361936

# %%
## time

import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1754159302.4475694
# 1754159304.4491794

# %%
## regualar expression


import re
pattern = r'\d+'
text = 'There are 123 apples and 456 oranges.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['123', '456']
