# %% [markdown]
# ### Flask FrameWork
#
# wsgi-  web server gatway interface
#
# jinja 2  template engine
#
# flask :- it is a complete web framework which is creator with the python programming languge.
