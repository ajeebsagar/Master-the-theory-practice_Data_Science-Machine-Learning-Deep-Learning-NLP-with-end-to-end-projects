# %% [markdown]
# Decorators
#
# Decorators are a powerful and flexible feature in python that allows you to modify the behavior of a function or class method. they are commonly used to add fuctionality to functions or methods without modifying their actual code. this lesson covers the basic of decorators, including how to create and use them.

# %%
## function copy
## closures
## decorators

# %%
## function copy
def welcome():
    return "Welcome to Python"

welcome()
# Out:
# 'Welcome to Python'

# %%
wel=welcome
print(wel())
del welcome
print(wel())
# Out:
# Welcome to Python
# Welcome to Python

# %%
## closures

def main_welcome():
    msg="welcome"
    def sub_welcome_method():
        print("welcome to the advance python course")

        print("please subscribe to the channel")
    return sub_welcome_method()   
main_welcome()
# Out:
# welcome to the advance python course
# please subscribe to the channel

# %%
## closures

def main_welcome(msg):
 
    def sub_welcome_method():
        print("welcome to the advance python course")
        print(msg)
        print("please subscribe to the channel")
    return sub_welcome_method()   
main_welcome("welcome to the channel")
# Out:
# welcome to the advance python course
# welcome to the channel
# please subscribe to the channel

# %%
def main_welcome(func, lst):

    def sub_welcome_method():
        print("welcome to the advance python course")
        print(func(lst))
        print("please learn these concepts properly")
    return sub_welcome_method()
main_welcome(len, [1, 2, 3, 4, 5, 6])
# Out:
# welcome to the advance python course
# 6
# please learn these concepts properly

# %%
### decorators

def main_welcome(func, list):
    def sub_welcome_method():
        print("welcome to the advance python course")
        func()
        print("please learn these concepts properly")
    return sub_welcome_method() 

def cource_introduction():
    print("this is a course on advance python")

coure_introduction = main_welcome(cource_introduction, [1, 2, 3, 4, 5, 6])
coure_introduction()    
main_welcome(cource_introduction)
# Out:
# welcome to the advance python course
# this is a course on advance python
# please learn these concepts properly
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 14
#      11     print("this is a course on advance python")
#      13 coure_introduction = main_welcome(cource_introduction, [1, 2, 3, 4, 5, 6])
# ---> 14 coure_introduction()
#      15 main_welcome(cource_introduction)
#
# TypeError: 'NoneType' object is not callable

# %%
@main_welcome
def cource_introduction():
    print("this is a course on advance python")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 @main_welcome
#       2 def cource_introduction():
#       3     print("this is a course on advance python")
#
# TypeError: main_welcome() missing 1 required positional argument: 'list'

# %%
### decorator

def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

@my_decorator
def say_hello():
    print("Hello!")

say_hello()
# Out:
# Something is happening before the function is called.
# Hello!
# Something is happening after the function is called.

# %%
## decorator with arguments
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper

    return decorator

@repeat (3)
def say_helllo():
    print("Hello!") 
say_helllo()
# Out:
# Hello!
# Hello!
# Hello!
