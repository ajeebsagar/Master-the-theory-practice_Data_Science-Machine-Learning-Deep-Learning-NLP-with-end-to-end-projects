# %% [markdown]
# sets are a built in data type in python used to store collection of unique items. they are unordered, meaning that hte element do not follow a specific order, and they do not fallow a specific order.

# %%
my_set =([1, 2, 3, 4, 5])
print(my_set)

my_set.add(7)
print(my_set)
my_set.add(7)
print(my_set)
# Out:
# [1, 2, 3, 4, 5]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 my_set =([1, 2, 3, 4, 5])
#       2 print(my_set)
# ----> 4 my_set.add(7)
#       5 print(my_set)
#       6 my_set.add(7)
#
# AttributeError: 'list' object has no attribute 'add'
