# %% [markdown]
# #### introduction to Streamlt
#
# Streamlit is an open-source app frmework for machine learning and data science projects. it allows you to create beautiful web applications for your machine learning and data science projects with simple python scripts.
